# %% [markdown]
# # Networks from Independence Assumptions
#
# This notebook constructs causal networks based on independence assumptions
# and prints the corresponding prediction formulas.`

# %%
# Install dependency (run once)
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\ahafeez7\appdata\local\anaconda3\lib\site-packages (3.6.1)

# %%
# Import library
import networkx as nx

# %%
# Case 1: I(X, Y)

G1 = nx.DiGraph()
G1.add_edges_from([("X", "Z"), ("Y", "Z")])

print("Case 1 Network Edges:", list(G1.edges()))
print("Prediction formula: P(Z | X, Y)")
# Out:
# Case 1 Network Edges: [('X', 'Z'), ('Y', 'Z')]
# Prediction formula: P(Z | X, Y)

# %%
# Case 2: I(X, Y), Not I(X, Y | Z)

G2 = nx.DiGraph()
G2.add_edges_from([("X", "Z"), ("Y", "Z")])

print("Case 2 Network Edges:", list(G2.edges()))
print("Prediction formula: P(Z | X, Y)")
# Out:
# Case 2 Network Edges: [('X', 'Z'), ('Y', 'Z')]
# Prediction formula: P(Z | X, Y)

# %%
# Case 3: I(X, Y), I(X, Y | Z), Y measured last

G3 = nx.DiGraph()
G3.add_edges_from([("Z", "X"), ("Z", "Y")])

print("Case 3 Network Edges:", list(G3.edges()))
print("Prediction formula: P(Y | Z)")
# Out:
# Case 3 Network Edges: [('Z', 'X'), ('Z', 'Y')]
# Prediction formula: P(Y | Z)

# %%
# Case 4: I(X, Y), I(X, Y | Z), I({X,Y}, W | Z), W measured last

G4 = nx.DiGraph()
G4.add_edges_from([("Z", "X"), ("Z", "Y"), ("Z", "W")])

print("Case 4 Network Edges:", list(G4.edges()))
print("Prediction formula: P(W | Z)")
# Out:
# Case 4 Network Edges: [('Z', 'X'), ('Z', 'Y'), ('Z', 'W')]
# Prediction formula: P(W | Z)

# %%
# Case 5: I(X, Y), I(Z, W), ordering constraints

G5 = nx.DiGraph()
G5.add_edges_from([("X", "Z"), ("Y", "W")])

print("Case 5 Network Edges:", list(G5.edges()))
print("Prediction formula: P(W | Y)")
# Out:
# Case 5 Network Edges: [('X', 'Z'), ('Y', 'W')]
# Prediction formula: P(W | Y)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ahafeez7\appdata\local\anaconda3\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ahafeez7\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ahafeez7\appdata\local\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ahafeez7\appdata\local\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ahafeez7\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\ahafeez7\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ahafeez7\appdata\local\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ahafeez7\appdata\local\anaconda3\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\ahafeez7\appdata\local\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ahafeez7\appdata\local\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ahafeez7\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import networkx as nx

# %%
# Optional: visualize one example network
import matplotlib.pyplot as plt

plt.figure()
# Recreate G4
G4 = nx.DiGraph()

nx.draw(G4, with_labels=True)
plt.title("Example Network (Case 4)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2 import matplotlib.pyplot as plt
#       4 plt.figure()
# ----> 5 nx.draw(G4, with_labels=True)
#       6 plt.title("Example Network (Case 4)")
#       7 plt.show()
#
# NameError: name 'G4' is not defined
